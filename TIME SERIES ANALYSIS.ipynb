# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path=(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr")

# %%
company_list=['AAPL_data.csv','GOOG_data.csv','MSFT_data.csv','AMZN_data.csv']
all_data=pd.DataFrame()
for file in company_list:
    current_df=pd.read_csv(path+'/'+file)
    all_data=pd.concat([all_data,current_df])
all_data.shape
# Out:
# (4752, 7)

# %%
all_data.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
all_data['date']=pd.to_datetime(all_data['date'])

# %%
#analyse closing price of all the stocks

# %%
tech_list=all_data['Name'].unique()

# %%
for i, company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.title(company)

# %%
plt.figure(figsize=(20,12))
for i, company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.title(company)

# %%
plt.figure(figsize=(90,40))
for i, company in enumerate(tech_list,1):
    plt.subplot(2,2,i)
    df=all_data[all_data['Name']==company]
    plt.plot(df['date'],df['close'])
    plt.xticks(rotation='vertical')
    plt.title(company)

# %%
#analyse the total volume of stock being traded each day

# %%
#analyse daily returns

# %%
#analyse daily price change in stock

# %%
df=pd.read_csv(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr/AAPL_data.csv")

# %%
df.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
df['Daily_Price_change']=df['close']-df['open']

# %%
df.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_Price_change
# 0              0.1400
# 1              0.4900
# 2             -1.6586
# 3             -0.0286
# 4              0.2957

# %%
df['1day %return']=((df['close']-df['open'])/df['close'])*100

# %%
df.head()
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#    Daily_Price_change  1day %return
# 0              0.1400      0.206325
# 1              0.4900      0.714688
# 2             -1.6586     -2.481344
# 3             -0.0286     -0.042869
# 4              0.2957      0.443624

# %%
#analyse monethyl mean of close feature

# %%
df2=df.copy()

# %%
df2.dtypes
# Out:
# date                   object
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# volume                  int64
# Name                   object
# Daily_Price_change    float64
# 1day %return          float64
# dtype: object

# %%
df2['data']=pd.to_datetime(df2['date'])

# %%
df2.set_index('date',inplace=True)

# %%
df2.head()
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#             Daily_Price_change  1day %return       data
# date
# 2013-02-08              0.1400      0.206325 2013-02-08
# 2013-02-11              0.4900      0.714688 2013-02-11
# 2013-02-12             -1.6586     -2.481344 2013-02-12
# 2013-02-13             -0.0286     -0.042869 2013-02-13
# 2013-02-14              0.2957      0.443624 2013-02-14

# %%
df2['2013-02-08':'2013-02-14']
# Out:
#                open     high      low    close     volume  Name  \
# date
# 2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL
#
#             Daily_Price_change  1day %return       data
# date
# 2013-02-08              0.1400      0.206325 2013-02-08
# 2013-02-11              0.4900      0.714688 2013-02-11
# 2013-02-12             -1.6586     -2.481344 2013-02-12
# 2013-02-13             -0.0286     -0.042869 2013-02-13
# 2013-02-14              0.2957      0.443624 2013-02-14

# %%
#performing multi variate analysis

# %%
#analyse whether stock prices of these tech companies (amazon,apple,google,microsoft)are correalated or not

# %%
aapl=pd.read_csv(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr/AAPL_data.csv")

# %%
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
amzn=pd.read_csv(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr/AMZN_data.csv")

# %%
amzn.head()
# Out:
#          date    open    high      low   close   volume  Name
# 0  2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN
# 1  2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN
# 2  2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN
# 3  2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN
# 4  2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN

# %%
msft=pd.read_csv(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr/MSFT_data.csv")

# %%
msft.head()
# Out:
#          date   open   high    low  close    volume  Name
# 0  2013-02-08  27.35  27.71  27.31  27.55  33318306  MSFT
# 1  2013-02-11  27.65  27.92  27.50  27.86  32247549  MSFT
# 2  2013-02-12  27.88  28.00  27.75  27.88  35990829  MSFT
# 3  2013-02-13  27.93  28.11  27.88  28.03  41715530  MSFT
# 4  2013-02-14  27.92  28.06  27.87  28.04  32663174  MSFT

# %%
goog=pd.read_csv(r"D:\DATA ANALYTICS PROJECTS\TIME SERIES (STOCK DATA)udemy\RESOURCES\NOT WORK\individual_stocks_5yr/GOOG_data.csv")

# %%
goog.head()
# Out:
#          date     open    high     low   close  volume  Name
# 0  2014-03-27  568.000  568.00  552.92  558.46   13052  GOOG
# 1  2014-03-28  561.200  566.43  558.67  559.99   41003  GOOG
# 2  2014-03-31  566.890  567.00  556.93  556.97   10772  GOOG
# 3  2014-04-01  558.710  568.45  558.71  567.16    7932  GOOG
# 4  2014-04-02  565.106  604.83  562.19  567.00  146697  GOOG

# %%
close=pd.DataFrame()

# %%
close['aapl']=aapl['close']
close['goog']=goog['close']
close['amzn']=amzn['close']
close['msft']=msft['close']

# %%
close.head()
# Out:
#       aapl    goog    amzn   msft
# 0  67.8542  558.46  261.95  27.55
# 1  68.5614  559.99  257.21  27.86
# 2  66.8428  556.97  258.70  27.88
# 3  66.7156  567.16  269.47  28.03
# 4  66.6556  567.00  269.24  28.04

# %%
import seaborn as sns
sns.pairplot(data=close)

# %%
sns.heatmap(close.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(close.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#value at risk analysis

# %%
#analyze daily returns of each stock and how they are co-related

# %%
aapl.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
data=pd.DataFrame()

# %%
data['aapl_change']=((aapl['close']-aapl['open'])/aapl['close'])*100
data['goog_change']=((goog['close']-goog['open'])/goog['close'])*100
data['amzn_change']=((amzn['close']-amzn['open'])/amzn['close'])*100
data['msft_change']=((msft['close']-msft['open'])/msft['close'])*100

# %%
data.head()
# Out:
#    aapl_change  goog_change  amzn_change  msft_change
# 0     0.206325    -1.708269     0.209964     0.725953
# 1     0.714688    -0.216075    -2.328836     0.753769
# 2    -2.481344    -1.781065    -0.189409     0.000000
# 3    -0.042869     1.489879     2.946525     0.356761
# 4     0.443624     0.334039     0.694548     0.427960

# %%
sns.pairplot(data=data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#value at risk analysis for tech companies

# %%
sns.distplot(data['aapl_change'])
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='aapl_change', ylabel='Density'>

# %%
#68% of entire data
data['aapl_change'].std()
# Out:
# 1.1871377131421237

# %%
#95% of entire data
data['aapl_change'].std()*2
# Out:
# 2.3742754262842474

# %%
#99.7% of entire data is
data['aapl_change'].std()*3
# Out:
# 3.561413139426371

# %%
data['aapl_change'].quantile(0.1)
# Out:
# -1.4246644227944307

# %%
data.describe()
# Out:
#        aapl_change  goog_change  amzn_change  msft_change
# count  1259.000000   975.000000  1259.000000  1259.000000
# mean     -0.000215    -0.012495    -0.000398     0.076404
# std       1.187138     1.092560     1.358679     1.059260
# min      -7.104299    -5.952266    -9.363077    -5.177618
# 25%      -0.658021    -0.551963    -0.738341    -0.509241
# 50%       0.042230     0.024951    -0.002623     0.061069
# 75%       0.715427     0.672649     0.852568     0.703264
# max       8.000388     4.943550     5.640265     4.861491

# %%
data.describe().T
# Out:
#               count      mean       std       min       25%       50%  \
# aapl_change  1259.0 -0.000215  1.187138 -7.104299 -0.658021  0.042230
# goog_change   975.0 -0.012495  1.092560 -5.952266 -0.551963  0.024951
# amzn_change  1259.0 -0.000398  1.358679 -9.363077 -0.738341 -0.002623
# msft_change  1259.0  0.076404  1.059260 -5.177618 -0.509241  0.061069
#
#                   75%       max
# aapl_change  0.715427  8.000388
# goog_change  0.672649  4.943550
# amzn_change  0.852568  5.640265
# msft_change  0.703264  4.861491
